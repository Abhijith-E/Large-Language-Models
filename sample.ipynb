# %%
documents = [
    "The capital of France is Paris.",
    "The Eiffel Tower is located in Paris.",
    "France is a country in Europe.",
    "Python is a popular programming language.",
    "Transformers are powerful language models."
]

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

doc_embeddings = embedding_model.encode(documents)

# %%
print(doc_embeddings)
# Out:
# [[ 0.10325699  0.03042021  0.02909573 ...  0.05853156  0.08586001
#   -0.00566983]
#  [ 0.06605354  0.03884846  0.01661568 ...  0.03093831  0.07990997
#    0.05157554]
#  [ 0.04392916  0.03398277  0.00548658 ...  0.04819132  0.08674994
#   -0.02615975]
#  [-0.03083177 -0.01335987 -0.00917529 ...  0.1205538   0.16613545
#    0.02672416]
#  [-0.03530493 -0.04294074  0.00499327 ...  0.06438494  0.071071
#   -0.00943326]]

# %%
import faiss
import numpy as np

dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)

index.add(np.array(doc_embeddings))

# %%
question = "Where is the Eiffel Tower?"


question_embedding = embedding_model.encode([question])


k = 2  
distances, indices = index.search(np.array(question_embedding), k)


retrieved_docs = [documents[i] for i in indices[0]]
print("Retrieved Docs:", retrieved_docs)
# Out:
# Retrieved Docs: ['The Eiffel Tower is located in Paris.', 'The capital of France is Paris.']
